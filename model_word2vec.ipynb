# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
import gensim
import gensim.downloader as api
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec, KeyedVectors
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'/content/SMSSpamCollection.txt', sep='\t', names=['label', 'text'])

# %%
lemmatizer = WordNetLemmatizer()

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus = []
for i in range(len(df)):
  message = re.sub('[^a-zA-Z]', ' ', df['text'][i])
  message = message.lower()
  message = message.split()
  message = [word for word in message if word not in stopwords.words('english')]
  message = ' '.join(message)
  corpus.append(message)

# %%
words = []
for sentence in corpus:
  sent_tokens = sent_tokenize(sentence)
  for sent in sent_tokens:
    words.append(simple_preprocess(sent))

# %%
words[:5]
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply'],
#  ['dun', 'say', 'early', 'hor', 'already', 'say'],
#  ['nah', 'think', 'goes', 'usf', 'lives', 'around', 'though']]

# %%
model = Word2Vec(words)

# %%
wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# List all words in vocabulary
model.wv.index_to_key[:30]
# Out:
# ['call',
#  'get',
#  'ur',
#  'gt',
#  'lt',
#  'ok',
#  'go',
#  'free',
#  'know',
#  'like',
#  'good',
#  'day',
#  'got',
#  'come',
#  'time',
#  'love',
#  'send',
#  'want',
#  'text',
#  'txt',
#  'one',
#  'going',
#  'need',
#  'home',
#  'stop',
#  'lor',
#  'sorry',
#  'today',
#  'see',
#  'still']

# %%
model.corpus_count
# Out:
# 5564

# %%
model.wv.similar_by_word('happy')
# Out:
# [('day', 0.9993436336517334),
#  ('dear', 0.9991540908813477),
#  ('new', 0.9990948438644409),
#  ('wish', 0.9990916848182678),
#  ('amp', 0.9990845322608948),
#  ('birthday', 0.999076247215271),
#  ('great', 0.9990759491920471),
#  ('love', 0.9990725517272949),
#  ('good', 0.9990459680557251),
#  ('said', 0.9990389943122864)]

# %%
def avg_word2vec(doc):
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key], axis=0)

# %%
X = []
for i in tqdm(range(len(words))):
  X.append(avg_word2vec(words[i]))
# Out:
# 100%|██████████| 5564/5564 [00:01<00:00, 5530.80it/s]

# %%
len(X)
# Out:
# 5564

# %%
df.shape
# Out:
# (5572, 2)

# %%
y = df[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label']).astype(int)
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5564,)

# %%
df = pd.concat([pd.DataFrame(X[i].reshape(1, -1)) for i in range(len(X))], ignore_index=True)

# %%
df.head()
# Out:
#          0         1         2         3   ...        96        97        98        99
# 0 -0.078511  0.183765  0.053795  0.090800  ...  0.147532 -0.273180  0.137404 -0.045766
# 1 -0.068497  0.161958  0.045265  0.077333  ...  0.123080 -0.243148  0.115697 -0.037108
# 2 -0.088543  0.201832  0.053131  0.107078  ...  0.165909 -0.311553  0.149080 -0.050672
# 3 -0.115220  0.276111  0.073750  0.133779  ...  0.225807 -0.409278  0.203771 -0.066639
# 4 -0.071212  0.169902  0.045504  0.085141  ...  0.133123 -0.242345  0.117546 -0.036514
#
# [5 rows x 100 columns]

# %%
df['output'] = y

# %%
df.head()
# Out:
#           0         1         2         3         4  ...        96        97        98        99  output
# 0 -0.078511  0.183765  0.053795  0.090800  0.111081  ...  0.147532 -0.273180  0.137404 -0.045766       1
# 1 -0.068497  0.161958  0.045265  0.077333  0.094020  ...  0.123080 -0.243148  0.115697 -0.037108       1
# 2 -0.088543  0.201832  0.053131  0.107078  0.122256  ...  0.165909 -0.311553  0.149080 -0.050672       0
# 3 -0.115220  0.276111  0.073750  0.133779  0.163778  ...  0.225807 -0.409278  0.203771 -0.066639       1
# 4 -0.071212  0.169902  0.045504  0.085141  0.100748  ...  0.133123 -0.242345  0.117546 -0.036514       1
#
# [5 rows x 101 columns]

# %%
df.isna().sum()
# Out:
# 0         74
# 1         74
# 2         74
# 3         74
# 4         74
#           ..
# 96        74
# 97        74
# 98        74
# 99        74
# output     0
# Length: 101, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# output    0
# Length: 101, dtype: int64

# %%
X = df.drop('output', axis=1)

# %%
X.head()
# Out:
#          0         1         2         3   ...        96        97        98        99
# 0 -0.078511  0.183765  0.053795  0.090800  ...  0.147532 -0.273180  0.137404 -0.045766
# 1 -0.068497  0.161958  0.045265  0.077333  ...  0.123080 -0.243148  0.115697 -0.037108
# 2 -0.088543  0.201832  0.053131  0.107078  ...  0.165909 -0.311553  0.149080 -0.050672
# 3 -0.115220  0.276111  0.073750  0.133779  ...  0.225807 -0.409278  0.203771 -0.066639
# 4 -0.071212  0.169902  0.045504  0.085141  ...  0.133123 -0.242345  0.117546 -0.036514
#
# [5 rows x 100 columns]

# %%
y = df['output']

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5559    0
# 5560    1
# 5561    1
# 5562    1
# 5563    1
# Name: output, Length: 5490, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=15)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(f'Accuracy score: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy score: 0.970873786407767

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.81      0.88       108
#            1       0.97      0.99      0.98       716
#
#     accuracy                           0.97       824
#    macro avg       0.96      0.90      0.93       824
# weighted avg       0.97      0.97      0.97       824
